# %%
import pandas as pd
import re
query = 'Alzheimer'
df = pd.read_csv(r'C:\Users\Vanessa\Downloads\Ironhack\M02-L05-introduction_to_API\Alzheimer_20150101_20220101.csv')

# %%
#cleaning columns
df.columns = df.columns.str.lower().str.strip()

# %%
df
# Out:
#                                                abstract  \
# 0     A group of Alzheimer’s experts and health advo...
# 1     Medicare officials are trying to determine whe...
# 2     Scientists who injected idle mice with blood f...
# 3     The drug, Aduhelm, has been mired in controver...
# 4     Newly published safety data shows that 41 perc...
# ...                                                 ...
# 1365  It may not be the cure-all to inequity, but we...
# 1366  When she’s not throwing molten wax on chandeli...
# 1367  Six years after they were first reported, debi...
# 1368  The magazine’s Ethicist columnist on how to ha...
# 1369  Gary Taubes’s “The Case Against Sugar” sugarco...
#
#                                                 web_url  \
# 0     https://www.nytimes.com/2021/12/20/health/alzh...
# 1     https://www.nytimes.com/2021/12/31/health/aduh...
# 2     https://www.nytimes.com/2021/12/08/science/mic...
# 3     https://www.nytimes.com/2021/11/17/business/bi...
# 4     https://www.nytimes.com/2021/11/22/health/aduh...
# ...                                                 ...
# 1365  https://www.nytimes.com/2019/01/20/smarter-liv...
# 1366  https://www.nytimes.com/2018/09/13/arts/design...
# 1367  https://www.nytimes.com/2021/06/04/world/canad...
# 1368  https://www.nytimes.com/2018/08/14/magazine/sh...
# 1369  https://www.nytimes.com/2017/01/02/books/revie...
#
#                                                 snippet  \
# 0     A group of Alzheimer’s experts and health advo...
# 1     Medicare officials are trying to determine whe...
# 2     Scientists who injected idle mice with blood f...
# 3     The drug, Aduhelm, has been mired in controver...
# 4     Newly published safety data shows that 41 perc...
# ...                                                 ...
# 1365  It may not be the cure-all to inequity, but we...
# 1366  When she’s not throwing molten wax on chandeli...
# 1367  Six years after they were first reported, debi...
# 1368  The magazine’s Ethicist columnist on how to ha...
# 1369  Gary Taubes’s “The Case Against Sugar” sugarco...
#
#                                          lead_paragraph print_section  \
# 0     Biogen slashed the price of its controversial ...             A
# 1     Federal officials are wrestling with a decisio...             A
# 2     What if something in the blood of an athlete c...             A
# 3     The drug maker Biogen said on Wednesday that a...             B
# 4     Concerns about safety risks of the controversi...             A
# ...                                                 ...           ...
# 1365  Welcome to the Smarter Living newsletter! Ever...             B
# 1366  WEST NEW YORK, N.J. — Two shrouded female figu...            AR
# 1367  MONTREAL — Forty-eight people from the same sm...             A
# 1368  I work in the architecture field as a designer...            MM
# 1369  THE CASE AGAINST SUGARBy Gary Taubes365 pp. Al...            BR
#
#       print_page              source  \
# 0           17.0  The New York Times
# 1            1.0  The New York Times
# 2           15.0  The New York Times
# 3            3.0  The New York Times
# 4           13.0  The New York Times
# ...          ...                 ...
# 1365         8.0  The New York Times
# 1366        21.0  The New York Times
# 1367         8.0  The New York Times
# 1368        20.0  The New York Times
# 1369         1.0  The New York Times
#
#                                              multimedia  \
# 0     [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 1     [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2     [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 3     [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 4     [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# ...                                                 ...
# 1365  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 1366  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 1367  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 1368  [{'rank': 0, 'subtype': 'popup', 'caption': No...
# 1369  [{'rank': 0, 'subtype': 'square320', 'caption'...
#
#                                                keywords  \
# 0     [{'name': 'subject', 'value': 'your-feed-scien...
# 1     [{'name': 'subject', 'value': 'Aduhelm (Drug)'...
# 2     [{'name': 'subject', 'value': 'Animal Cognitio...
# 3     [{'name': 'subject', 'value': 'Aduhelm (Drug)'...
# 4     [{'name': 'subject', 'value': 'your-feed-scien...
# ...                                                 ...
# 1365  [{'name': 'subject', 'value': 'Wages and Salar...
# 1366  [{'name': 'subject', 'value': 'Art', 'rank': 1...
# 1367  [{'name': 'subject', 'value': 'Brain', 'rank':...
# 1368  [{'name': 'subject', 'value': 'Education (K-12...
# 1369  [{'name': 'subject', 'value': 'Books and Liter...
#
#                       pub_date  ...  \
# 0     2021-12-20T22:25:39+0000  ...
# 1     2021-12-31T16:40:08+0000  ...
# 2     2021-12-08T16:00:11+0000  ...
# 3     2021-11-17T16:07:32+0000  ...
# 4     2021-11-22T16:00:09+0000  ...
# ...                        ...  ...
# 1365  2019-01-21T03:00:01+0000  ...
# 1366  2018-09-13T14:00:07+0000  ...
# 1367  2021-06-04T14:43:22+0000  ...
# 1368  2018-08-14T09:00:01+0000  ...
# 1369  2017-01-02T10:00:04+0000  ...
#
#                                 headline.print_headline headline.name  \
# 0     Drugmaker Slashes Price Of Alzheimer’s Medicat...           NaN
# 1                      A Drug’s Hurdle: Nod by Medicare           NaN
# 2     Study of Mice Reveals A Boost for Brainpower I...           NaN
# 3     Biogen Says New Drug for Alzheimer’s Is Unlike...           NaN
# 4     Death of Participant In Alzheimer’s Trial Spur...           NaN
# ...                                                 ...           ...
# 1365       Want to Close the Pay Gap? Try Transparency.           NaN
# 1366                The Pure Joy of Flinging Molten Wax           NaN
# 1367           Brain Ailment Mystifies Canadian Doctors           NaN
# 1368  Should I Speak Up About My Client’s Drinking P...           NaN
# 1369                                 How Sweet It Isn’t           NaN
#
#      headline.seo headline.sub          byline.original  \
# 0             NaN          NaN           By Pam Belluck
# 1             NaN          NaN           By Pam Belluck
# 2             NaN          NaN           By Pam Belluck
# 3             NaN          NaN       By Rebecca Robbins
# 4             NaN          NaN           By Pam Belluck
# ...           ...          ...                      ...
# 1365          NaN          NaN          By Kristin Wong
# 1366          NaN          NaN     By Hilarie M. Sheets
# 1367          NaN          NaN          By Dan Bilefsky
# 1368          NaN          NaN  By Kwame Anthony Appiah
# 1369          NaN          NaN            By Dan Barber
#
#                                           byline.person byline.organization  \
# 0     [{'firstname': 'Pam', 'middlename': None, 'las...                 NaN
# 1     [{'firstname': 'Pam', 'middlename': None, 'las...                 NaN
# 2     [{'firstname': 'Pam', 'middlename': None, 'las...                 NaN
# 3     [{'firstname': 'Rebecca', 'middlename': None, ...                 NaN
# 4     [{'firstname': 'Pam', 'middlename': None, 'las...                 NaN
# ...                                                 ...                 ...
# 1365  [{'firstname': 'Kristin', 'middlename': None, ...                 NaN
# 1366  [{'firstname': 'Hilarie', 'middlename': None, ...                 NaN
# 1367  [{'firstname': 'Dan', 'middlename': None, 'las...                 NaN
# 1368  [{'firstname': 'Kwame', 'middlename': 'Anthony...                 NaN
# 1369  [{'firstname': 'Dan', 'middlename': None, 'las...                 NaN
#
#      subsection_name query_consulta  slideshow_credits
# 0                NaN      Alzheimer                NaN
# 1                NaN      Alzheimer                NaN
# 2                NaN      Alzheimer                NaN
# 3                NaN      Alzheimer                NaN
# 4                NaN      Alzheimer                NaN
# ...              ...            ...                ...
# 1365             NaN      Alzheimer                NaN
# 1366    Art & Design      Alzheimer                NaN
# 1367          Canada      Alzheimer                NaN
# 1368             NaN      Alzheimer                NaN
# 1369     Book Review      Alzheimer                NaN
#
# [1370 rows x 30 columns]

# %%
#selecting desired columns from the original dataframe
partial_df = df[['query_consulta','pub_date','source', 'headline.main','headline.print_headline','snippet','lead_paragraph','keywords']]
partial_df.columns = ['query', 'pub_date', 'source', 'headline1', 'headline2','snippet','lead_paragraph','keywords']
partial_df
# Out:
#           query                  pub_date              source  \
# 0     Alzheimer  2021-12-20T22:25:39+0000  The New York Times
# 1     Alzheimer  2021-12-31T16:40:08+0000  The New York Times
# 2     Alzheimer  2021-12-08T16:00:11+0000  The New York Times
# 3     Alzheimer  2021-11-17T16:07:32+0000  The New York Times
# 4     Alzheimer  2021-11-22T16:00:09+0000  The New York Times
# ...         ...                       ...                 ...
# 1365  Alzheimer  2019-01-21T03:00:01+0000  The New York Times
# 1366  Alzheimer  2018-09-13T14:00:07+0000  The New York Times
# 1367  Alzheimer  2021-06-04T14:43:22+0000  The New York Times
# 1368  Alzheimer  2018-08-14T09:00:01+0000  The New York Times
# 1369  Alzheimer  2017-01-02T10:00:04+0000  The New York Times
#
#                                               headline1  \
# 0     Biogen Slashes Price of Alzheimer’s Drug Aduhe...
# 1     Decision Looms That Could Determine Fate of Al...
# 2            Can an Athlete’s Blood Enhance Brainpower?
# 3     Biogen’s Alzheimer’s drug is unlikely to win E...
# 4     Concerns Grow Over Safety of Aduhelm After Dea...
# ...                                                 ...
# 1365  Want to Close the Pay Gap? Pay Transparency Wi...
# 1366  An Artist Who Champions and Channels Female Vo...
# 1367  Mysterious Brain Syndrome Stumps Canadian Doctors
# 1368  Should I Speak Up About My Client’s Drinking P...
# 1369          What Not to Eat: ‘The Case Against Sugar’
#
#                                               headline2  \
# 0     Drugmaker Slashes Price Of Alzheimer’s Medicat...
# 1                      A Drug’s Hurdle: Nod by Medicare
# 2     Study of Mice Reveals A Boost for Brainpower I...
# 3     Biogen Says New Drug for Alzheimer’s Is Unlike...
# 4     Death of Participant In Alzheimer’s Trial Spur...
# ...                                                 ...
# 1365       Want to Close the Pay Gap? Try Transparency.
# 1366                The Pure Joy of Flinging Molten Wax
# 1367           Brain Ailment Mystifies Canadian Doctors
# 1368  Should I Speak Up About My Client’s Drinking P...
# 1369                                 How Sweet It Isn’t
#
#                                                 snippet  \
# 0     A group of Alzheimer’s experts and health advo...
# 1     Medicare officials are trying to determine whe...
# 2     Scientists who injected idle mice with blood f...
# 3     The drug, Aduhelm, has been mired in controver...
# 4     Newly published safety data shows that 41 perc...
# ...                                                 ...
# 1365  It may not be the cure-all to inequity, but we...
# 1366  When she’s not throwing molten wax on chandeli...
# 1367  Six years after they were first reported, debi...
# 1368  The magazine’s Ethicist columnist on how to ha...
# 1369  Gary Taubes’s “The Case Against Sugar” sugarco...
#
#                                          lead_paragraph  \
# 0     Biogen slashed the price of its controversial ...
# 1     Federal officials are wrestling with a decisio...
# 2     What if something in the blood of an athlete c...
# 3     The drug maker Biogen said on Wednesday that a...
# 4     Concerns about safety risks of the controversi...
# ...                                                 ...
# 1365  Welcome to the Smarter Living newsletter! Ever...
# 1366  WEST NEW YORK, N.J. — Two shrouded female figu...
# 1367  MONTREAL — Forty-eight people from the same sm...
# 1368  I work in the architecture field as a designer...
# 1369  THE CASE AGAINST SUGARBy Gary Taubes365 pp. Al...
#
#                                                keywords
# 0     [{'name': 'subject', 'value': 'your-feed-scien...
# 1     [{'name': 'subject', 'value': 'Aduhelm (Drug)'...
# 2     [{'name': 'subject', 'value': 'Animal Cognitio...
# 3     [{'name': 'subject', 'value': 'Aduhelm (Drug)'...
# 4     [{'name': 'subject', 'value': 'your-feed-scien...
# ...                                                 ...
# 1365  [{'name': 'subject', 'value': 'Wages and Salar...
# 1366  [{'name': 'subject', 'value': 'Art', 'rank': 1...
# 1367  [{'name': 'subject', 'value': 'Brain', 'rank':...
# 1368  [{'name': 'subject', 'value': 'Education (K-12...
# 1369  [{'name': 'subject', 'value': 'Books and Liter...
#
# [1370 rows x 8 columns]

# %%
#cleaning 'pub_date' column
partial_df['pub_date'] = partial_df['pub_date'].apply(lambda x: re.findall('\d{4}', x))
partial_df['pub_date'] = [i[0] for i in partial_df['pub_date']]
# Out:
# C:\Users\Vanessa\AppData\Local\Temp\ipykernel_27400\2312738720.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partial_df['pub_date'] = partial_df['pub_date'].apply(lambda x: re.findall('\d{4}', x))
# C:\Users\Vanessa\AppData\Local\Temp\ipykernel_27400\2312738720.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partial_df['pub_date'] = [i[0] for i in partial_df['pub_date']]

# %%
# keeping only lines with query in 'headline1/2' or 'snippet' or 'keywords'
partial_df.fillna = np.nan
mask = (partial_df['headline1'].str.contains(f'{query}', flags = re.I) | partial_df['headline2'].str.contains(f'{query}', flags = re.I)| partial_df['snippet'].str.contains(f'{query}', flags = re.I) |partial_df['lead_paragraph'].str.contains(f'{query}', flags = re.I) | partial_df['keywords'].astype(str).str.contains(f'{query}', flags = re.I))
final_df = partial_df[mask]

# %%
final_df
# Out:
#           query                  pub_date              source  \
# 0     Alzheimer  2021-12-20T22:25:39+0000  The New York Times
# 1     Alzheimer  2021-12-31T16:40:08+0000  The New York Times
# 2     Alzheimer  2021-12-08T16:00:11+0000  The New York Times
# 3     Alzheimer  2021-11-17T16:07:32+0000  The New York Times
# 4     Alzheimer  2021-11-22T16:00:09+0000  The New York Times
# ...         ...                       ...                 ...
# 1256  Alzheimer  2016-05-20T16:29:01+0000  The New York Times
# 1259  Alzheimer  2016-01-22T13:32:03+0000  The New York Times
# 1307  Alzheimer  2015-03-20T13:46:57+0000  The New York Times
# 1323  Alzheimer  2018-08-25T00:21:59+0000  The New York Times
# 1363  Alzheimer  2017-08-08T17:59:18+0000  The New York Times
#
#                                               headline1  \
# 0     Biogen Slashes Price of Alzheimer’s Drug Aduhe...
# 1     Decision Looms That Could Determine Fate of Al...
# 2            Can an Athlete’s Blood Enhance Brainpower?
# 3     Biogen’s Alzheimer’s drug is unlikely to win E...
# 4     Concerns Grow Over Safety of Aduhelm After Dea...
# ...                                                 ...
# 1256  In Sweden, an Experiment Turns Shorter Workday...
# 1259  ‘Living on Paper: Letters From Iris Murdoch, 1...
# 1307     Rolling With the Punches, at Any Stage of Life
# 1323  Caring for Aging Parents, With an Eye on the B...
# 1363  How Rebecca Solnit Became the Voice of the Res...
#
#                                               headline2  \
# 0     Drugmaker Slashes Price Of Alzheimer’s Medicat...
# 1                      A Drug’s Hurdle: Nod by Medicare
# 2     Study of Mice Reveals A Boost for Brainpower I...
# 3     Biogen Says New Drug for Alzheimer’s Is Unlike...
# 4     Death of Participant In Alzheimer’s Trial Spur...
# ...                                                 ...
# 1256                                 The 6-Hour Workday
# 1259                                   Her Kind Regards
# 1307     Rolling With the Punches, at Any Stage of Life
# 1323                         Caught in a Broker’s Churn
# 1363                               The Cassandra Effect
#
#                                                 snippet  \
# 0     A group of Alzheimer’s experts and health advo...
# 1     Medicare officials are trying to determine whe...
# 2     Scientists who injected idle mice with blood f...
# 3     The drug, Aduhelm, has been mired in controver...
# 4     Newly published safety data shows that 41 perc...
# ...                                                 ...
# 1256  A trial in the city of Gothenburg mandates a s...
# 1259  Murdoch set aside most afternoons for letters,...
# 1307  Most people recover after even the most diffic...
# 1323  How one woman discovered excessive and unautho...
# 1363  In recent years, the writer has amassed a new ...
#
#                                          lead_paragraph  \
# 0     Biogen slashed the price of its controversial ...
# 1     Federal officials are wrestling with a decisio...
# 2     What if something in the blood of an athlete c...
# 3     The drug maker Biogen said on Wednesday that a...
# 4     Concerns about safety risks of the controversi...
# ...                                                 ...
# 1256  GOTHENBURG, Sweden — Arturo Perez used to come...
# 1259  At 17, Iris Murdoch was asked what she intende...
# 1307  OVER the last eight years, Teresa Mears has cy...
# 1323  Tracey Dewart faced a daunting task last summe...
# 1363  Subjects that the author and essayist Rebecca ...
#
#                                                keywords
# 0     [{'name': 'subject', 'value': 'your-feed-scien...
# 1     [{'name': 'subject', 'value': 'Aduhelm (Drug)'...
# 2     [{'name': 'subject', 'value': 'Animal Cognitio...
# 3     [{'name': 'subject', 'value': 'Aduhelm (Drug)'...
# 4     [{'name': 'subject', 'value': 'your-feed-scien...
# ...                                                 ...
# 1256  [{'name': 'subject', 'value': 'Working Hours',...
# 1259  [{'name': 'subject', 'value': 'Books and Liter...
# 1307  [{'name': 'subject', 'value': 'Layoffs and Job...
# 1323  [{'name': 'subject', 'value': 'Consumer Protec...
# 1363  [{'name': 'persons', 'value': 'Solnit, Rebecca...
#
# [467 rows x 8 columns]
